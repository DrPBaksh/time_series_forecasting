# %% [markdown]
# # Time Series Forecasting 3 : Extra
#
# This notebook is going to demonstrate how to apply further time series algorithms to time dependant data. I will also attatch individual notebooks on the techniques we are looking at today that will go into more detail.
#
# **Today**
# - Import data
# - Time Series Decomposition
# - Make Prediction using ETS algorithm
# - Decide on the appropriate ARMA SARIMA ARIMA algorthm and apply
# - Apply XGboost Regression for time series forecasting
# - Apply FB Prophet

# %%
import pandas as pd
import matplotlib.pyplot as plt

from statsmodels.graphics import tsaplots 
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('store_daily_sales.csv', parse_dates= True)
df
# Out:
#             date          sales
# 0     2013-01-01    2511.618999
# 1     2013-01-02  496092.417944
# 2     2013-01-03  361461.231124
# 3     2013-01-04  354459.677093
# 4     2013-01-05  477350.121229
# ...          ...            ...
# 1679  2017-08-11  826373.722022
# 1680  2017-08-12  792630.535079
# 1681  2017-08-13  865639.677471
# 1682  2017-08-14  760922.406081
# 1683  2017-08-15  762661.935939
#
# [1684 rows x 2 columns]

# %%
df.set_index('date', inplace = True)

# %%
gaps = pd.date_range(start=min(df.index), 
                     end=max(df.index),
                     freq='D').difference(df.index)
gaps
# Out:
# DatetimeIndex(['2013-12-25', '2014-12-25', '2015-12-25', '2016-12-25'], dtype='datetime64[ns]', freq=None)

# %%
df.head()
# Out:
#                     sales
# date
# 2013-01-01    2511.618999
# 2013-01-02  496092.417944
# 2013-01-03  361461.231124
# 2013-01-04  354459.677093
# 2013-01-05  477350.121229

# %%
df.plot()
fig = plt.gcf()
fig.set_size_inches(30, 5)

# %%
X = pd.read_csv('https://github.com/DrPBaksh/workshop-data/blob/main/temperature_load.csv?raw=true')
X.date_time = pd.to_datetime(X.date_time)
X.head()
# Out:
#             date_time  total load actual  temp_mean        date      time
# 0 2015-01-01 00:00:00            25385.0    270.475  2015-01-01  00:00:00
# 1 2015-01-01 01:00:00            24382.0    270.475  2015-01-01  01:00:00
# 2 2015-01-01 02:00:00            22734.0    269.686  2015-01-01  02:00:00
# 3 2015-01-01 03:00:00            21286.0    269.686  2015-01-01  03:00:00
# 4 2015-01-01 04:00:00            20264.0    269.686  2015-01-01  04:00:00

# %%
X.dtypes
# Out:
# date_time            datetime64[ns]
# total load actual           float64
# temp_mean                   float64
# date                         object
# time                         object
# dtype: object

# %%
X.set_index('date_time').plot(y = 'total load actual')
fig = plt.gcf()
fig.set_size_inches(20, 10)

# %%
X.set_index('date_time').plot(y = 'total load actual')
plt.xlim(['2015-01-01', '2015-04-01'])
fig = plt.gcf()
fig.set_size_inches(20, 10)

# %%
X.head()
# Out:
#             date_time  total load actual  temp_mean        date      time
# 0 2015-01-01 00:00:00            25385.0    270.475  2015-01-01  00:00:00
# 1 2015-01-01 01:00:00            24382.0    270.475  2015-01-01  01:00:00
# 2 2015-01-01 02:00:00            22734.0    269.686  2015-01-01  02:00:00
# 3 2015-01-01 03:00:00            21286.0    269.686  2015-01-01  03:00:00
# 4 2015-01-01 04:00:00            20264.0    269.686  2015-01-01  04:00:00

# %%
X = X.set_index('date_time')

# %%
X.index.freq = 'H'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:962, in DatetimeLikeArrayMixin._validate_frequency(cls, index, freq, **kwargs)
#     961     if not np.array_equal(index.asi8, on_freq.asi8):
# --> 962         raise ValueError
#     963 except ValueError as e:
#
# ValueError:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 X.index.freq = 'H'
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\extension.py:78, in _inherit_from_data.<locals>.fset(self, value)
#      77 def fset(self, value):
# ---> 78     setattr(self._data, name, value)
#
# ...

# %%
gaps = pd.date_range(start=min(X.index), 
                     end=max(X.index),
                     freq='H').difference(X.index)
gaps
# Out:
# DatetimeIndex(['2015-03-29 02:00:00', '2016-03-27 02:00:00',
#                '2017-03-26 02:00:00', '2018-03-25 02:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# This is probably been caused by the change in time

# %%
X.index.to_frame().duplicated().sum()
# Out:
# 4

# %%
X = X[~X.index.to_frame().duplicated()]

# %%
cleaned_date = pd.date_range(start=min(X.index), 
                     end=max(X.index),
                     freq='H')

# %%
X_cleaned = pd.DataFrame(cleaned_date, columns = ['date_time'])
cleaned_date.shape, X.shape
# Out:
# ((35064,), (35060, 4))

# %%
X_cleaned = X_cleaned.merge(X, how = 'left', on= 'date_time')

# %%
X_cleaned.set_index('date_time', inplace = True)

# %%
X_cleaned.index.freq = 'H'

# %%
X_cleaned.isna().sum()
# Out:
# total load actual    4
# temp_mean            4
# date                 4
# time                 4
# dtype: int64

# %%
X_cleaned = X_cleaned.fillna(method='bfill')

# %%
X_cleaned
# Out:
#                      total load actual  temp_mean        date      time
# date_time
# 2015-01-01 00:00:00            25385.0    270.475  2015-01-01  00:00:00
# 2015-01-01 01:00:00            24382.0    270.475  2015-01-01  01:00:00
# 2015-01-01 02:00:00            22734.0    269.686  2015-01-01  02:00:00
# 2015-01-01 03:00:00            21286.0    269.686  2015-01-01  03:00:00
# 2015-01-01 04:00:00            20264.0    269.686  2015-01-01  04:00:00
# ...                                ...        ...         ...       ...
# 2018-12-31 19:00:00            30653.0    285.650  2018-12-31  19:00:00
# 2018-12-31 20:00:00            29735.0    283.150  2018-12-31  20:00:00
# 2018-12-31 21:00:00            28071.0    281.650  2018-12-31  21:00:00
# 2018-12-31 22:00:00            25801.0    280.150  2018-12-31  22:00:00
# 2018-12-31 23:00:00            24455.0    279.150  2018-12-31  23:00:00
#
# [35064 rows x 4 columns]

# %% [markdown]
# ## Identifying the Multiple Seasonalities in the time series

# %%
from statsmodels.graphics.tsaplots import plot_acf
acf = plot_acf(X_cleaned['total load actual'])
plt.grid('minor')
plt.show()

# %%
day = X_cleaned['total load actual'].groupby(pd.Grouper(freq = 'D')).mean()
acf = plot_acf(day)
plt.show()

# %%
week = X_cleaned['total load actual'].groupby(pd.Grouper(freq = 'W')).mean()
acf = plot_acf(week)
plt.show()

# %%
month = X_cleaned['total load actual'].groupby(pd.Grouper(freq = 'M')).mean()
acf = plot_acf(month)
plt.show()

# %%
X.head()
# Out:
#                      total load actual  temp_mean        date      time
# date_time
# 2015-01-01 00:00:00            25385.0    270.475  2015-01-01  00:00:00
# 2015-01-01 01:00:00            24382.0    270.475  2015-01-01  01:00:00
# 2015-01-01 02:00:00            22734.0    269.686  2015-01-01  02:00:00
# 2015-01-01 03:00:00            21286.0    269.686  2015-01-01  03:00:00
# 2015-01-01 04:00:00            20264.0    269.686  2015-01-01  04:00:00

# %%
import statsmodels.api as sm


# Fit an ETS model with two seasonal periods
ets_model = sm.tsa.ETSModel(X['total load actual'].head(1000) ,error='add', trend=None, seasonal=None, seasonal_periods=[24, int(24*7), int(365*24)]).fit()

# Generate a 30-step-ahead forecast
forecast = ets_model.forecast(steps=30)

# Plot the residuals of the fitted model
residuals = ets_model.resid
plt.plot(residuals)
plt.title('Residuals of ETS model')
plt.show()

forecast
# Out:
# C:\Users\PeterBaksh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)
# 2015-02-11 16:00:00    28534.093208
# 2015-02-11 17:00:00    28534.093208
# 2015-02-11 18:00:00    28534.093208
# 2015-02-11 19:00:00    28534.093208
# 2015-02-11 20:00:00    28534.093208
# 2015-02-11 21:00:00    28534.093208
# 2015-02-11 22:00:00    28534.093208
# 2015-02-11 23:00:00    28534.093208
# 2015-02-12 00:00:00    28534.093208
# 2015-02-12 01:00:00    28534.093208
# 2015-02-12 02:00:00    28534.093208
# 2015-02-12 03:00:00    28534.093208
# 2015-02-12 04:00:00    28534.093208
# 2015-02-12 05:00:00    28534.093208
# 2015-02-12 06:00:00    28534.093208
# 2015-02-12 07:00:00    28534.093208
# 2015-02-12 08:00:00    28534.093208
# 2015-02-12 09:00:00    28534.093208
# 2015-02-12 10:00:00    28534.093208
# 2015-02-12 11:00:00    28534.093208
# ...

# %%
fit.forecast(100)
# Out:
# C:\Users\PeterBaksh\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 35060    24461.786959
# 35061    24461.786959
# 35062    24461.786959
# 35063    24461.786959
# 35064    24461.786959
#              ...
# 35155    24461.786959
# 35156    24461.786959
# 35157    24461.786959
# 35158    24461.786959
# 35159    24461.786959
# Length: 100, dtype: float64

# %%
forecast
# Out:
# 35060    24461.786959
# 35061    24461.786959
# 35062    24461.786959
# 35063    24461.786959
# 35064    24461.786959
# 35065    24461.786959
# 35066    24461.786959
# 35067    24461.786959
# 35068    24461.786959
# 35069    24461.786959
# 35070    24461.786959
# 35071    24461.786959
# 35072    24461.786959
# 35073    24461.786959
# 35074    24461.786959
# 35075    24461.786959
# 35076    24461.786959
# 35077    24461.786959
# 35078    24461.786959
# 35079    24461.786959
# 35080    24461.786959
# 35081    24461.786959
# 35082    24461.786959
# 35083    24461.786959
# 35084    24461.786959
# 35085    24461.786959
# 35086    24461.786959
# 35087    24461.786959
# 35088    24461.786959
# 35089    24461.786959
# dtype: float64

# %% [markdown]
# Clearly multiple seasonality does not work here

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 5>()
#       1 from statsmodels.tsa.seasonal import STL
#       4 # Perform STL decomposition
# ----> 5 stl = STL(data, period=[24, int(24*7)])
#       6 res = stl.fit()
#       8 # Plot the original time series
#
# File statsmodels\tsa\_stl.pyx:222, in statsmodels.tsa._stl.STL.__init__()
#
# ValueError: period must be a positive integer >= 2

# %%
tsaplots.plot_acf(airlines_df['de-trended'],missing='drop',lags=22,alpha=0.05)
